# %%
import pandas as pd

# %%
# df=pd.DataFrame([[2,6,9],[6,1,4],[9,2,7]],columns=["A","B","C"])
df=pd.DataFrame([["Zunaisha",22,"girl"],["Eman",20,"girl"],["Abdul Hadi",15,"boy"]],columns=["Names","Age","Gender"])

# %%
# df.head()         #shows first 5 rows
# df.head(1)
# df.tail()           #shows last 5 rows
df.tail(1)
# Out:
#         Names  Age Gender
# 2  Abdul Hadi   15    boy

# %%
df=pd.DataFrame([["Zunaisha",22,"girl"],["Eman",20,"girl"],["Abdul Hadi",15,"boy"]],columns=["Names","Age","Gender"])

# %%
df.columns           #column names
# Out:
# Index(['Names', 'Age', 'Gender'], dtype='object')

# %%
# df.index
df.index.to_list()
# Out:
# [0, 1, 2]

# %%
df=pd.DataFrame([["Zunaisha",22,"girl"],["Eman",20,"girl"],["Abdul Hadi",15,"boy"]],columns=["Names","Age","Gender"],index=["first","second","third"])

# %%
df.head()
# Out:
#              Names  Age Gender
# first     Zunaisha   22   girl
# second        Eman   20   girl
# third   Abdul Hadi   15    boy

# %%
df.index
# Out:
# Index(['first', 'second', 'third'], dtype='object')

# %%
df.index.tolist()
# Out:
# ['first', 'second', 'third']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, first to third
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Names   3 non-null      object
#  1   Age     3 non-null      int64
#  2   Gender  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 96.0+ bytes

# %%
df.describe()              #details of int column
# Out:
#              Age
# count   3.000000
# mean   19.000000
# std     3.605551
# min    15.000000
# 25%    17.500000
# 50%    20.000000
# 75%    21.000000
# max    22.000000

# %%
df.nunique()               #unique values
# df['Names'].nunique()
# df['Gender'].nunique()
# Out:
# Names     3
# Age       3
# Gender    2
# dtype: int64

# %%
df.shape         #(rows,columns)
# df.size          #total elements
# Out:
# (3, 3)
