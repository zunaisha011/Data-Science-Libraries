# %%
import numpy as np

# %%
price=np.array([100,200,300,400,500])
discount=25
final_price= price - (price * discount/100)
final_price
# Out:
# array([ 75., 150., 225., 300., 375.])

# %%
money=np.array([10,20,30])
add=100
new=money+add
new
# Out:
# array([110, 120, 130])
